# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Read .csv file and import to pandas

# %%
df1 = pd.read_csv(r'C:\Users\ADMIN\Downloads\playlist_2010to2023.csv', encoding='ISO-8859-1')
df1.head()
# Out:
#                                         playlist_url  year  \
# 0  https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
# 1  https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
# 2  https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
# 3  https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
# 4  https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
#
#                  track_id              track_name  track_popularity  \
# 0  6naxalmIoLFWR0siv8dnQQ  Oops!...I Did It Again                81
# 1  2m1hi0nfMR9vdGC8UcrnwU    All The Small Things                83
# 2  3y4LxiYMgDl4RethdzpmNe                 Breathe                66
# 3  0v1XpBHnsbkCn7iJ9Ucr1l            It's My Life                81
# 4  62bOmKYxYg7dhrC6gH9vFn             Bye Bye Bye                75
#
#                      album               artist_id     artist_name  \
# 0  Oops!... I Did It Again  26dSoYclwsYLMAKD3tpOr4  Britney Spears
# ...

# %%
df1.shape
# Out:
# (2400, 23)

# %%
df1.isnull().sum()
# Out:
# playlist_url         0
# year                 0
# track_id             0
# track_name           0
# track_popularity     0
# album                0
# artist_id            0
# artist_name          0
# artist_genres        0
# artist_popularity    0
# danceability         0
# energy               0
# key                  0
# loudness             0
# mode                 0
# speechiness          0
# acousticness         0
# instrumentalness     0
# liveness             0
# valence              0
# tempo                0
# duration_ms          0
# time_signature       0
# dtype: int64

# %%
df2 = df1.drop(['time_signature','tempo','valence','liveness','instrumentalness','acousticness','speechiness','mode','loudness','key','energy','danceability'],axis = 'columns')
df2.shape
# Out:
# (2400, 11)

# %%
df3 = df2.describe()
df3.head()
# Out:
#               year  track_popularity  artist_popularity    duration_ms
# count  2400.000000       2400.000000        2400.000000    2400.000000
# mean   2011.500000         70.277083          75.882500  224695.583750
# std       6.923629         12.958245          12.016746   41652.938998
# min    2000.000000          0.000000          36.000000   97393.000000
# 25%    2005.750000         65.000000          68.000000  199050.500000

# %%
plt.figure(figsize = (10,4))
sns.heatmap(df3.corr(), annot=True, cmap = plt.cm.Greens)
plt.show()

# %%
df2.isnull().values.any()
# Out:
# np.False_

# %%
df2.head(20)
# Out:
#                                          playlist_url  year  \
# 0   https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
# 1   https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
# 2   https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
# 3   https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
# 4   https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
# 5   https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
# 6   https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
# 7   https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
# 8   https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
# 9   https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
# 10  https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
# 11  https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
# 12  https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
# 13  https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
# 14  https://open.spotify.com/playlist/37i9dQZF1DWU...  2000
# ...

# %%
df2.album.unique().shape
df2.track_popularity.unique().shape
# Out:
# (72,)

# %%
df3 = df2.groupby('album')['track_name'].agg(', '.join).reset_index()
df3.head()
# Out:
#                 album                          track_name
# 0                 "7"  Reach, Never Had A Dream Come True
# 1  "Awaken, My Love!"                             Redbone
# 2                  #3      Hall of Fame (feat. will.i.am)
# 3             #SELFIE                             #SELFIE
# 4          #willpower                      Scream & Shout

# %%
df4 = df2.groupby('album').sum()['track_popularity']
df4.head()
# Out:
# album
# "7"                   119
# "Awaken, My Love!"     83
# #3                     70
# #SELFIE                63
# #willpower             80
# Name: track_popularity, dtype: int64

# %%
df3['track_popularity'] = ''
df3['track_popularity'] = [(lambda track_popularity: track_popularity)(track_popularity) for albums, track_popularity in df4.items()]
df3.head()
# Out:
#                 album                          track_name  track_popularity
# 0                 "7"  Reach, Never Had A Dream Come True               119
# 1  "Awaken, My Love!"                             Redbone                83
# 2                  #3      Hall of Fame (feat. will.i.am)                70
# 3             #SELFIE                             #SELFIE                63
# 4          #willpower                      Scream & Shout                80
